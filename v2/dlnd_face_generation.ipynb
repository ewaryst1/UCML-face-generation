# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
data_dir = '../processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/0.4.0/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
from torch.utils.data import DataLoader
def get_dataloader(batch_size, image_size, data_dir='../processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    
    transform = transforms.Compose([transforms.Resize(image_size), # resize to image_size x image_size
                                    transforms.ToTensor()])

    # get training and test directories
    image_path = data_dir
    train_path = image_path #os.path.join(image_path, image_type)

    # define datasets using ImageFolder
    train_dataset = datasets.ImageFolder(train_path, transform)

    # create and return DataLoaders
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

    return train_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should see square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, int(plot_size/2), idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    
    return x*(max-min)+min

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-1.)
# Max:  tensor(0.9922)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# helper conv function
def conv(in_channels, out_channels, kernel_size=4, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    
    # append conv layer
    layers.append(conv_layer)

    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)


# helper deconv function
def deconv(in_channels, out_channels, kernel_size = 4, stride=2, padding=1, batch_norm=True):
    """Creates a transposed-convolutional layer, with optional batch normalization.
    """
    ## create a sequence of transpose + optional batch norm layers
    layers = []
    deconv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    
    # append conv layer
    layers.append(deconv_layer)
    
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        # inputsize: 32 x 32 x 3
        self.layer1 = conv(3, conv_dim, batch_norm=False)
        # inputsize: 16 x 16 x cd
        self.layer2 = conv(conv_dim, conv_dim*2)
        # inputsize: 8 x 8 x cd * 2
        self.layer3 = conv(conv_dim*2, conv_dim*4)
        self.relu = nn.LeakyReLU(0.2)
        final_conv_dim = conv_dim*4
        # inputsize: 4 * 4 * cd * 4
        self.dropout = nn.Dropout(0.3)
        self.fc = nn.Linear(4*4*conv_dim*4, 1)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        x = self.relu(self.layer1(x))
        x = self.relu(self.layer2(x))
        x = self.relu(self.layer3(x))
        batch_size = x.shape[0]
        x = x.view(batch_size, -1)
        x = self.dropout(x)
        x = self.fc(x)

        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        self.fc = nn.Linear(z_size, 4*4*conv_dim*4)
        self.deconv1 = deconv(conv_dim*4, conv_dim*2)
        self.deconv2 = deconv(conv_dim*2, conv_dim)
        self.deconv3 = deconv(conv_dim, 3, batch_norm=False)
        
        self.relu = nn.LeakyReLU(0.2)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc(x)
        
        x = x.view(-1, self.conv_dim*4, 4, 4)

        x = self.relu(self.deconv1(x))
        x = self.relu(self.deconv2(x))
        x = torch.tanh(self.deconv3(x))
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    mean, std_dev = 0, 0.02

    # TODO: Apply initial weights to convolutional and linear layers
    if (classname in set(["ConvTranspose2d", "Conv2d", "Linear"])):
        m.weight.data.normal_(mean, std_dev)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (relu): LeakyReLU(negative_slope=0.2)
#   (dropout): Dropout(p=0.3)
#   (fc): Linear(in_features=4096, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=4096, bias=True)
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (relu): LeakyReLU(negative_slope=0.2)
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    labels = torch.ones(batch_size) # real labels = 1
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim
learning_rate = 0.001
beta1= 0.5
beta2= 0.999
momentum = [beta1, beta2]

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), learning_rate, momentum)
g_optimizer = optim.Adam(G.parameters(), learning_rate, momentum)

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def new_z(sample_size, z_size):
    z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    z = torch.from_numpy(z).float()
    # move z to GPU if available
    if train_on_gpu:
        z = z.cuda()
    return z

def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = new_z(sample_size, z_size)

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================

            if train_on_gpu:
                real_images = real_images.cuda()

            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            d_out = D(real_images)
            fake_out = G(new_z(sample_size, z_size))
            d_fake_out = D(fake_out)
            d_loss = real_loss(d_out) + fake_loss(d_fake_out)
            
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            fake_out = G(new_z(sample_size, z_size))
            d_fake_out = D(fake_out)
            g_loss = real_loss(d_fake_out)

            g_loss.backward()
            g_optimizer.step()
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        with torch.no_grad():
            samples_z = G(fixed_z)
            samples_z = samples_z.detach().cpu()
            samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 20


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   20] | d_loss: 1.6502 | g_loss: 2.8763
# Epoch [    1/   20] | d_loss: 0.4485 | g_loss: 2.6831
# Epoch [    1/   20] | d_loss: 0.9586 | g_loss: 1.8425
# Epoch [    1/   20] | d_loss: 1.6231 | g_loss: 4.5991
# Epoch [    1/   20] | d_loss: 0.8835 | g_loss: 2.7146
# Epoch [    1/   20] | d_loss: 1.2014 | g_loss: 2.1645
# Epoch [    1/   20] | d_loss: 1.0027 | g_loss: 2.2783
# Epoch [    1/   20] | d_loss: 1.0121 | g_loss: 3.3821
# Epoch [    1/   20] | d_loss: 0.7780 | g_loss: 1.6956
# Epoch [    1/   20] | d_loss: 1.3473 | g_loss: 0.9274
# Epoch [    1/   20] | d_loss: 0.7780 | g_loss: 1.1863
# Epoch [    1/   20] | d_loss: 0.8146 | g_loss: 1.6995
# Epoch [    1/   20] | d_loss: 0.8380 | g_loss: 1.3682
# Epoch [    1/   20] | d_loss: 0.8961 | g_loss: 2.0892
# Epoch [    1/   20] | d_loss: 0.9246 | g_loss: 1.5069
# Epoch [    2/   20] | d_loss: 1.1764 | g_loss: 1.1561
# Epoch [    2/   20] | d_loss: 1.9026 | g_loss: 1.1590
# Epoch [    2/   20] | d_loss: 0.9217 | g_loss: 2.4846
# Epoch [    2/   20] | d_loss: 0.7261 | g_loss: 1.4824
# Epoch [    2/   20] | d_loss: 1.1221 | g_loss: 2.1960
# Epoch [    2/   20] | d_loss: 0.9606 | g_loss: 1.2866
# Epoch [    2/   20] | d_loss: 0.7419 | g_loss: 1.6652
# Epoch [    2/   20] | d_loss: 0.4241 | g_loss: 3.2883
# Epoch [    2/   20] | d_loss: 0.9101 | g_loss: 1.4648
# Epoch [    2/   20] | d_loss: 0.7409 | g_loss: 3.2503
# Epoch [    2/   20] | d_loss: 0.9096 | g_loss: 1.4161
# Epoch [    2/   20] | d_loss: 0.8661 | g_loss: 2.7521
# Epoch [    2/   20] | d_loss: 0.5880 | g_loss: 1.7060
# Epoch [    2/   20] | d_loss: 0.4693 | g_loss: 0.3194
# Epoch [    2/   20] | d_loss: 1.0062 | g_loss: 1.7354
# Epoch [    3/   20] | d_loss: 0.5417 | g_loss: 2.5105
# Epoch [    3/   20] | d_loss: 0.5831 | g_loss: 2.8012
# Epoch [    3/   20] | d_loss: 0.7684 | g_loss: 2.5368
# Epoch [    3/   20] | d_loss: 0.2958 | g_loss: 3.5796
# Epoch [    3/   20] | d_loss: 0.8591 | g_loss: 3.3927
# Epoch [    3/   20] | d_loss: 0.4378 | g_loss: 1.3073
# Epoch [    3/   20] | d_loss: 0.1128 | g_loss: 0.8833
# Epoch [    3/   20] | d_loss: 0.4323 | g_loss: 4.0137
# Epoch [    3/   20] | d_loss: 0.4441 | g_loss: 2.1212
# Epoch [    3/   20] | d_loss: 0.6184 | g_loss: 1.0169
# Epoch [    3/   20] | d_loss: 0.5469 | g_loss: 4.5418
# Epoch [    3/   20] | d_loss: 0.3248 | g_loss: 3.0323
# Epoch [    3/   20] | d_loss: 0.9755 | g_loss: 2.2480
# Epoch [    3/   20] | d_loss: 0.5587 | g_loss: 0.9288
# Epoch [    3/   20] | d_loss: 0.7009 | g_loss: 2.9956
# Epoch [    4/   20] | d_loss: 0.5308 | g_loss: 4.2025
# Epoch [    4/   20] | d_loss: 0.9543 | g_loss: 8.7553
# Epoch [    4/   20] | d_loss: 0.4023 | g_loss: 3.7191
# Epoch [    4/   20] | d_loss: 0.9058 | g_loss: 0.8154
# Epoch [    4/   20] | d_loss: 0.1110 | g_loss: 2.1911
# Epoch [    4/   20] | d_loss: 0.1691 | g_loss: 4.7573
# Epoch [    4/   20] | d_loss: 0.3327 | g_loss: 3.8202
# Epoch [    4/   20] | d_loss: 0.6402 | g_loss: 2.2952
# Epoch [    4/   20] | d_loss: 0.3304 | g_loss: 1.8013
# Epoch [    4/   20] | d_loss: 0.9468 | g_loss: 2.8932
# Epoch [    4/   20] | d_loss: 0.0950 | g_loss: 2.8657
# Epoch [    4/   20] | d_loss: 0.0664 | g_loss: 3.7713
# Epoch [    4/   20] | d_loss: 0.1050 | g_loss: 3.8298
# Epoch [    4/   20] | d_loss: 0.7106 | g_loss: 3.7200
# Epoch [    4/   20] | d_loss: 0.1566 | g_loss: 8.8522
# Epoch [    5/   20] | d_loss: 0.0650 | g_loss: 3.4908
# Epoch [    5/   20] | d_loss: 0.0411 | g_loss: 3.4963
# Epoch [    5/   20] | d_loss: 1.1574 | g_loss: 1.2760
# Epoch [    5/   20] | d_loss: 0.3454 | g_loss: 4.3301
# Epoch [    5/   20] | d_loss: 0.2026 | g_loss: 2.6840
# Epoch [    5/   20] | d_loss: 0.0859 | g_loss: 8.6077
# Epoch [    5/   20] | d_loss: 0.2557 | g_loss: 2.2157
# Epoch [    5/   20] | d_loss: 0.1929 | g_loss: 4.9463
# Epoch [    5/   20] | d_loss: 0.0657 | g_loss: 8.5638
# Epoch [    5/   20] | d_loss: 0.2402 | g_loss: 4.4549
# Epoch [    5/   20] | d_loss: 0.2312 | g_loss: 3.0966
# Epoch [    5/   20] | d_loss: 0.4381 | g_loss: 4.4292
# Epoch [    5/   20] | d_loss: 0.0175 | g_loss: 4.1577
# Epoch [    5/   20] | d_loss: 0.1381 | g_loss: 6.5936
# Epoch [    5/   20] | d_loss: 0.0345 | g_loss: 4.7689
# Epoch [    6/   20] | d_loss: 0.1585 | g_loss: 1.6067
# Epoch [    6/   20] | d_loss: 0.0868 | g_loss: 7.6513
# Epoch [    6/   20] | d_loss: 0.4738 | g_loss: 1.0051
# Epoch [    6/   20] | d_loss: 0.4882 | g_loss: 4.4935
# Epoch [    6/   20] | d_loss: 1.8048 | g_loss: 3.0763
# Epoch [    6/   20] | d_loss: 0.1114 | g_loss: 2.2589
# Epoch [    6/   20] | d_loss: 0.0425 | g_loss: 2.9492
# Epoch [    6/   20] | d_loss: 0.8200 | g_loss: 5.3491
# Epoch [    6/   20] | d_loss: 0.0118 | g_loss: 4.5867
# Epoch [    6/   20] | d_loss: 0.5368 | g_loss: 4.1667
# Epoch [    6/   20] | d_loss: 0.4867 | g_loss: 7.7648
# Epoch [    6/   20] | d_loss: 0.0754 | g_loss: 7.7361
# Epoch [    6/   20] | d_loss: 0.1270 | g_loss: 5.3742
# Epoch [    6/   20] | d_loss: 0.1031 | g_loss: 11.7381
# Epoch [    6/   20] | d_loss: 0.2361 | g_loss: 3.6187
# Epoch [    7/   20] | d_loss: 0.0895 | g_loss: 2.3075
# Epoch [    7/   20] | d_loss: 0.0843 | g_loss: 5.1667
# Epoch [    7/   20] | d_loss: 0.3683 | g_loss: 9.1953
# Epoch [    7/   20] | d_loss: 0.1768 | g_loss: 5.6790
# Epoch [    7/   20] | d_loss: 0.0856 | g_loss: 5.1957
# Epoch [    7/   20] | d_loss: 0.0436 | g_loss: 8.0773
# Epoch [    7/   20] | d_loss: 0.7000 | g_loss: 9.3663
# Epoch [    7/   20] | d_loss: 0.1586 | g_loss: 4.6348
# Epoch [    7/   20] | d_loss: 0.5994 | g_loss: 5.6551
# Epoch [    7/   20] | d_loss: 0.3075 | g_loss: 9.3708
# Epoch [    7/   20] | d_loss: 0.0563 | g_loss: 4.9564
# Epoch [    7/   20] | d_loss: 0.1834 | g_loss: 3.5050
# Epoch [    7/   20] | d_loss: 0.0440 | g_loss: 5.6719
# Epoch [    7/   20] | d_loss: 0.7143 | g_loss: 5.6544
# Epoch [    7/   20] | d_loss: 0.0275 | g_loss: 7.8962
# Epoch [    8/   20] | d_loss: 0.1580 | g_loss: 3.1647
# Epoch [    8/   20] | d_loss: 0.5130 | g_loss: 5.0068
# Epoch [    8/   20] | d_loss: 0.0307 | g_loss: 7.9054
# Epoch [    8/   20] | d_loss: 0.0872 | g_loss: 2.9354
# Epoch [    8/   20] | d_loss: 0.1035 | g_loss: 5.5745
# Epoch [    8/   20] | d_loss: 0.3277 | g_loss: 2.7917
# Epoch [    8/   20] | d_loss: 0.1685 | g_loss: 6.5219
# Epoch [    8/   20] | d_loss: 0.1804 | g_loss: 4.5208
# Epoch [    8/   20] | d_loss: 0.1323 | g_loss: 5.7890
# Epoch [    8/   20] | d_loss: 0.2674 | g_loss: 3.4009
# Epoch [    8/   20] | d_loss: 0.0095 | g_loss: 8.2350
# Epoch [    8/   20] | d_loss: 0.1474 | g_loss: 2.5329
# Epoch [    8/   20] | d_loss: 0.2787 | g_loss: 6.0312
# Epoch [    8/   20] | d_loss: 0.9310 | g_loss: 6.5076
# Epoch [    8/   20] | d_loss: 0.3871 | g_loss: 3.7643
# Epoch [    9/   20] | d_loss: 0.0067 | g_loss: 2.6186
# Epoch [    9/   20] | d_loss: 0.0237 | g_loss: 5.2435
# Epoch [    9/   20] | d_loss: 0.0195 | g_loss: 5.4615
# Epoch [    9/   20] | d_loss: 0.0171 | g_loss: 6.7704
# Epoch [    9/   20] | d_loss: 0.1435 | g_loss: 5.7527
# Epoch [    9/   20] | d_loss: 0.1636 | g_loss: 4.2591
# Epoch [    9/   20] | d_loss: 0.0373 | g_loss: 5.9481
# Epoch [    9/   20] | d_loss: 0.0269 | g_loss: 5.0091
# Epoch [    9/   20] | d_loss: 0.0191 | g_loss: 7.2138
# Epoch [    9/   20] | d_loss: 0.0413 | g_loss: 8.1436
# Epoch [    9/   20] | d_loss: 0.0700 | g_loss: 10.3206
# Epoch [    9/   20] | d_loss: 0.0149 | g_loss: 5.4824
# Epoch [    9/   20] | d_loss: 0.1382 | g_loss: 5.6732
# Epoch [    9/   20] | d_loss: 0.0301 | g_loss: 14.3803
# Epoch [    9/   20] | d_loss: 0.0251 | g_loss: 6.6097
# Epoch [   10/   20] | d_loss: 0.1826 | g_loss: 1.9428
# Epoch [   10/   20] | d_loss: 0.1633 | g_loss: 6.2877
# Epoch [   10/   20] | d_loss: 0.4041 | g_loss: 9.7441
# Epoch [   10/   20] | d_loss: 0.0599 | g_loss: 12.0559
# Epoch [   10/   20] | d_loss: 0.9414 | g_loss: 9.0058
# Epoch [   10/   20] | d_loss: 0.0209 | g_loss: 3.7694
# Epoch [   10/   20] | d_loss: 0.1632 | g_loss: 6.0409
# Epoch [   10/   20] | d_loss: 0.0595 | g_loss: 4.7540
# Epoch [   10/   20] | d_loss: 0.4270 | g_loss: 1.6319
# Epoch [   10/   20] | d_loss: 0.0382 | g_loss: 3.1338
# Epoch [   10/   20] | d_loss: 0.0328 | g_loss: 8.0252
# Epoch [   10/   20] | d_loss: 0.0068 | g_loss: 6.8199
# Epoch [   10/   20] | d_loss: 0.0921 | g_loss: 8.5148
# Epoch [   10/   20] | d_loss: 0.4501 | g_loss: 8.9105
# Epoch [   10/   20] | d_loss: 0.2817 | g_loss: 6.2316
# Epoch [   11/   20] | d_loss: 0.0993 | g_loss: 6.1799
# Epoch [   11/   20] | d_loss: 0.0369 | g_loss: 7.3987
# Epoch [   11/   20] | d_loss: 0.2359 | g_loss: 5.6731
# Epoch [   11/   20] | d_loss: 0.0067 | g_loss: 5.9177
# Epoch [   11/   20] | d_loss: 0.1234 | g_loss: 9.2274
# Epoch [   11/   20] | d_loss: 0.0030 | g_loss: 4.4305
# Epoch [   11/   20] | d_loss: 0.0471 | g_loss: 4.4776
# Epoch [   11/   20] | d_loss: 0.7263 | g_loss: 4.7667
# Epoch [   11/   20] | d_loss: 0.1774 | g_loss: 6.1527
# Epoch [   11/   20] | d_loss: 0.8495 | g_loss: 2.5083
# Epoch [   11/   20] | d_loss: 0.0660 | g_loss: 8.3091
# Epoch [   11/   20] | d_loss: 0.0740 | g_loss: 5.3581
# Epoch [   11/   20] | d_loss: 0.0650 | g_loss: 3.6457
# Epoch [   11/   20] | d_loss: 0.1977 | g_loss: 8.1433
# Epoch [   11/   20] | d_loss: 0.0365 | g_loss: 3.2011
# Epoch [   12/   20] | d_loss: 0.4509 | g_loss: 8.1346
# Epoch [   12/   20] | d_loss: 0.0600 | g_loss: 6.2374
# Epoch [   12/   20] | d_loss: 0.0139 | g_loss: 6.3523
# Epoch [   12/   20] | d_loss: 0.9382 | g_loss: 1.3097
# Epoch [   12/   20] | d_loss: 0.1355 | g_loss: 10.5484
# Epoch [   12/   20] | d_loss: 0.0562 | g_loss: 5.9352
# Epoch [   12/   20] | d_loss: 0.0174 | g_loss: 10.6470
# Epoch [   12/   20] | d_loss: 0.0773 | g_loss: 3.7066
# Epoch [   12/   20] | d_loss: 0.9593 | g_loss: 12.8305
# Epoch [   12/   20] | d_loss: 0.0500 | g_loss: 4.3662
# Epoch [   12/   20] | d_loss: 0.0480 | g_loss: 4.2331
# Epoch [   12/   20] | d_loss: 0.0628 | g_loss: 10.3224
# Epoch [   12/   20] | d_loss: 0.0094 | g_loss: 7.6678
# Epoch [   12/   20] | d_loss: 0.0015 | g_loss: 6.5209
# Epoch [   12/   20] | d_loss: 1.2100 | g_loss: 5.8691
# Epoch [   13/   20] | d_loss: 0.0147 | g_loss: 14.7952
# Epoch [   13/   20] | d_loss: 0.0161 | g_loss: 16.4658
# Epoch [   13/   20] | d_loss: 0.0504 | g_loss: 5.9705
# Epoch [   13/   20] | d_loss: 0.0457 | g_loss: 7.0838
# Epoch [   13/   20] | d_loss: 0.0404 | g_loss: 8.2921
# Epoch [   13/   20] | d_loss: 0.3571 | g_loss: 6.9092
# Epoch [   13/   20] | d_loss: 0.1797 | g_loss: 8.9428
# Epoch [   13/   20] | d_loss: 0.0320 | g_loss: 6.3712
# Epoch [   13/   20] | d_loss: 0.0334 | g_loss: 4.6666
# Epoch [   13/   20] | d_loss: 0.3860 | g_loss: 7.7594
# Epoch [   13/   20] | d_loss: 0.0097 | g_loss: 6.7745
# Epoch [   13/   20] | d_loss: 0.1005 | g_loss: 6.1833
# Epoch [   13/   20] | d_loss: 0.0068 | g_loss: 11.5308
# Epoch [   13/   20] | d_loss: 0.0233 | g_loss: 4.9183
# Epoch [   13/   20] | d_loss: 0.0994 | g_loss: 7.3939
# Epoch [   14/   20] | d_loss: 0.0324 | g_loss: 12.4091
# Epoch [   14/   20] | d_loss: 0.0072 | g_loss: 8.7054
# Epoch [   14/   20] | d_loss: 0.1268 | g_loss: 13.0994
# Epoch [   14/   20] | d_loss: 0.1342 | g_loss: 4.7880
# Epoch [   14/   20] | d_loss: 0.0521 | g_loss: 10.8060
# Epoch [   14/   20] | d_loss: 0.1209 | g_loss: 5.1641
# Epoch [   14/   20] | d_loss: 0.0104 | g_loss: 5.0371
# Epoch [   14/   20] | d_loss: 0.2086 | g_loss: 2.8358
# Epoch [   14/   20] | d_loss: 0.0048 | g_loss: 8.3831
# Epoch [   14/   20] | d_loss: 0.0656 | g_loss: 5.3398
# Epoch [   14/   20] | d_loss: 0.1706 | g_loss: 13.5347
# Epoch [   14/   20] | d_loss: 0.0089 | g_loss: 10.6294
# Epoch [   14/   20] | d_loss: 0.0010 | g_loss: 6.2237
# Epoch [   14/   20] | d_loss: 0.1068 | g_loss: 1.0421
# Epoch [   14/   20] | d_loss: 0.1646 | g_loss: 4.4645
# Epoch [   15/   20] | d_loss: 0.0460 | g_loss: 7.3309
# Epoch [   15/   20] | d_loss: 0.0621 | g_loss: 4.4321
# Epoch [   15/   20] | d_loss: 0.0119 | g_loss: 5.9698
# Epoch [   15/   20] | d_loss: 0.1345 | g_loss: 8.7604
# Epoch [   15/   20] | d_loss: 0.0910 | g_loss: 8.3366
# Epoch [   15/   20] | d_loss: 0.0995 | g_loss: 7.9558
# Epoch [   15/   20] | d_loss: 0.1840 | g_loss: 0.3373
# Epoch [   15/   20] | d_loss: 0.1239 | g_loss: 5.6297
# Epoch [   15/   20] | d_loss: 0.0582 | g_loss: 3.9797
# Epoch [   15/   20] | d_loss: 0.0022 | g_loss: 6.1479
# Epoch [   15/   20] | d_loss: 0.0008 | g_loss: 6.6297
# Epoch [   15/   20] | d_loss: 0.0120 | g_loss: 7.0616
# Epoch [   15/   20] | d_loss: 0.0206 | g_loss: 7.0339
# Epoch [   15/   20] | d_loss: 0.0094 | g_loss: 10.4509
# Epoch [   15/   20] | d_loss: 0.0216 | g_loss: 6.1536
# Epoch [   16/   20] | d_loss: 0.0962 | g_loss: 5.7397
# Epoch [   16/   20] | d_loss: 0.0465 | g_loss: 6.9280
# Epoch [   16/   20] | d_loss: 0.0028 | g_loss: 7.1936
# Epoch [   16/   20] | d_loss: 0.0364 | g_loss: 6.3188
# Epoch [   16/   20] | d_loss: 0.1479 | g_loss: 4.5457
# Epoch [   16/   20] | d_loss: 0.1629 | g_loss: 10.7246
# Epoch [   16/   20] | d_loss: 0.0076 | g_loss: 9.4937
# Epoch [   16/   20] | d_loss: 0.0004 | g_loss: 10.4213
# Epoch [   16/   20] | d_loss: 0.0070 | g_loss: 11.3138
# Epoch [   16/   20] | d_loss: 0.0001 | g_loss: 7.0546
# Epoch [   16/   20] | d_loss: 0.0021 | g_loss: 8.3648
# Epoch [   16/   20] | d_loss: 0.0004 | g_loss: 11.9265
# Epoch [   16/   20] | d_loss: 0.0433 | g_loss: 7.8906
# Epoch [   16/   20] | d_loss: 0.0054 | g_loss: 10.2382
# Epoch [   16/   20] | d_loss: 0.1474 | g_loss: 11.4287
# Epoch [   17/   20] | d_loss: 0.1496 | g_loss: 6.2396
# Epoch [   17/   20] | d_loss: 0.0003 | g_loss: 12.2155
# Epoch [   17/   20] | d_loss: 0.2198 | g_loss: 10.2033
# Epoch [   17/   20] | d_loss: 0.2513 | g_loss: 11.4371
# Epoch [   17/   20] | d_loss: 0.0417 | g_loss: 12.2365
# Epoch [   17/   20] | d_loss: 0.2999 | g_loss: 3.1952
# Epoch [   17/   20] | d_loss: 0.0410 | g_loss: 7.0270
# Epoch [   17/   20] | d_loss: 0.0285 | g_loss: 1.8237
# Epoch [   17/   20] | d_loss: 0.1584 | g_loss: 6.3479
# Epoch [   17/   20] | d_loss: 0.0578 | g_loss: 6.0075
# Epoch [   17/   20] | d_loss: 0.1278 | g_loss: 12.7953
# Epoch [   17/   20] | d_loss: 0.0384 | g_loss: 4.7748
# Epoch [   17/   20] | d_loss: 0.0067 | g_loss: 10.9271
# Epoch [   17/   20] | d_loss: 0.0041 | g_loss: 8.8303
# Epoch [   17/   20] | d_loss: 0.0199 | g_loss: 4.6444
# Epoch [   18/   20] | d_loss: 0.0432 | g_loss: 6.3663
# Epoch [   18/   20] | d_loss: 0.0940 | g_loss: 6.5076
# Epoch [   18/   20] | d_loss: 0.0269 | g_loss: 5.8213
# Epoch [   18/   20] | d_loss: 0.5051 | g_loss: 3.4848
# Epoch [   18/   20] | d_loss: 0.0467 | g_loss: 13.5946
# Epoch [   18/   20] | d_loss: 0.0308 | g_loss: 8.1091
# Epoch [   18/   20] | d_loss: 0.0006 | g_loss: 3.0407
# Epoch [   18/   20] | d_loss: 0.0009 | g_loss: 5.2716
# Epoch [   18/   20] | d_loss: 0.1063 | g_loss: 8.7566
# Epoch [   18/   20] | d_loss: 0.2310 | g_loss: 4.7097
# Epoch [   18/   20] | d_loss: 0.0169 | g_loss: 8.5352
# Epoch [   18/   20] | d_loss: 0.0430 | g_loss: 11.5399
# Epoch [   18/   20] | d_loss: 3.3963 | g_loss: 10.9835
# Epoch [   18/   20] | d_loss: 0.0006 | g_loss: 8.4766
# Epoch [   18/   20] | d_loss: 0.0019 | g_loss: 9.9261
# Epoch [   19/   20] | d_loss: 0.1414 | g_loss: 6.0480
# Epoch [   19/   20] | d_loss: 0.0387 | g_loss: 8.1641
# Epoch [   19/   20] | d_loss: 0.0193 | g_loss: 6.7599
# Epoch [   19/   20] | d_loss: 0.0910 | g_loss: 7.9284
# Epoch [   19/   20] | d_loss: 0.0080 | g_loss: 12.1461
# Epoch [   19/   20] | d_loss: 0.0060 | g_loss: 6.0839
# Epoch [   19/   20] | d_loss: 0.0487 | g_loss: 5.8217
# Epoch [   19/   20] | d_loss: 0.0895 | g_loss: 7.2495
# Epoch [   19/   20] | d_loss: 0.0078 | g_loss: 7.5934
# Epoch [   19/   20] | d_loss: 0.5985 | g_loss: 1.9128
# Epoch [   19/   20] | d_loss: 0.0407 | g_loss: 3.7013
# Epoch [   19/   20] | d_loss: 0.0032 | g_loss: 9.1189
# Epoch [   19/   20] | d_loss: 1.1186 | g_loss: 8.8338
# Epoch [   19/   20] | d_loss: 0.0147 | g_loss: 8.9333
# Epoch [   19/   20] | d_loss: 0.1971 | g_loss: 7.0146
# Epoch [   20/   20] | d_loss: 0.1893 | g_loss: 3.3294
# Epoch [   20/   20] | d_loss: 0.1330 | g_loss: 5.3869
# Epoch [   20/   20] | d_loss: 0.0167 | g_loss: 6.3921
# Epoch [   20/   20] | d_loss: 0.0755 | g_loss: 8.0121
# Epoch [   20/   20] | d_loss: 0.0886 | g_loss: 6.8544
# Epoch [   20/   20] | d_loss: 0.0033 | g_loss: 8.6586
# Epoch [   20/   20] | d_loss: 0.0429 | g_loss: 10.7935
# Epoch [   20/   20] | d_loss: 0.1565 | g_loss: 5.9519
# Epoch [   20/   20] | d_loss: 0.0078 | g_loss: 9.8822
# Epoch [   20/   20] | d_loss: 0.0768 | g_loss: 10.0013
# Epoch [   20/   20] | d_loss: 0.0149 | g_loss: 5.4368
# Epoch [   20/   20] | d_loss: 0.6106 | g_loss: 5.0434
# Epoch [   20/   20] | d_loss: 1.2385 | g_loss: 5.9131
# Epoch [   20/   20] | d_loss: 0.0307 | g_loss: 2.3124
# Epoch [   20/   20] | d_loss: 0.0081 | g_loss: 6.1068

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
for i in range(0, n_epochs, 1):
    view_samples(i, samples)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)
#
# All generated faces are white. Some parts of the face show artefacts that do not look correct. Most faces look female. This is of course due to the given training data.
#
# I also tested smaller models which gave already good results but with lower resolution and more noise. Increasing the size could also lead to better results, maybe reducing the batch size could also help.
#
# Some faces look better after just some epochs, some look better at the end of the training. This is probably related to the observed increasing generator loss fluctuation. We see that the images get overall better the more epochs we train. We could hope to get even better models when training more epochs.
# I tried different learning rates but I could not see that this influences the result very much.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
